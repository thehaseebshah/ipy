# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import sympy as sy

# %%
x = sy.Symbol('x')

# %%
y = sy.Symbol('y')

# %%
z = sy.Symbol('z')

# %%
x
# Out:
# x

# %%
y
# Out:
# y

# %%
z
# Out:
# z

# %%
z.diff()
# Out:
# 1

# %%
(z**2).diff()
# Out:
# 2*z

# %%
m=2

# %%
c=10

# %%
x = np.linspace(-5,5,100)
y = m*x+c
plt.plot(x,y)

# %%
x  = np.linspace(-5,5,100)
y = np.sin(x)
plt.plot(x,y)
